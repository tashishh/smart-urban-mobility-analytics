# %%
import pandas as pd
import numpy as np

# Load the raw dataset - adjust path if needed
df = pd.read_csv('../data/raw/test.csv')

print("✅ Dataset loaded successfully!")
print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# ✅ Dataset loaded successfully!
# Rows: 625,134
# Columns: 9

# %%
# Look at the first 5 rows
df.head()
# Out:
#           id  vendor_id  pickup_datetime  passenger_count  pickup_longitude  \
# 0  id3004672          1  6/30/2016 23:59                1        -73.988129
# 1  id3505355          1  6/30/2016 23:59                1        -73.964203
# 2  id1217141          1  6/30/2016 23:59                1        -73.997437
# 3  id2150126          2  6/30/2016 23:59                1        -73.956070
# 4  id1598245          1  6/30/2016 23:59                1        -73.970215
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag
# 0        40.732029         -73.990173         40.756680                  N
# 1        40.679993         -73.959808         40.655403                  N
# 2        40.737583         -73.986160         40.729523                  N
# 3        40.771900         -73.986427         40.730469                  N
# 4        40.761475         -73.961510         40.755890                  N

# %%
print("=== COLUMN NAMES AND DATA TYPES ===")
print(df.dtypes)
# Out:
# === COLUMN NAMES AND DATA TYPES ===
# id                     object
# vendor_id               int64
# pickup_datetime        object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# dtype: object

# %%
print("=== MISSING VALUES PER COLUMN ===")
missing = df.isnull().sum()
missing_pct = (df.isnull().sum() / len(df)) * 100

missing_report = pd.DataFrame({
    'Missing Count': missing,
    'Missing %': missing_pct.round(2)
})
print(missing_report)
# Out:
# === MISSING VALUES PER COLUMN ===
#                     Missing Count  Missing %
# id                              0        0.0
# vendor_id                       0        0.0
# pickup_datetime                 0        0.0
# passenger_count                 0        0.0
# pickup_longitude                0        0.0
# pickup_latitude                 0        0.0
# dropoff_longitude               0        0.0
# dropoff_latitude                0        0.0
# store_and_fwd_flag              0        0.0

# %%
print("=== BASIC STATISTICS ===")
df.describe()
# Out:
# === BASIC STATISTICS ===
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  625134.000000    625134.000000     625134.000000    625134.000000
# mean        1.534884         1.661765        -73.973614        40.750927
# std         0.498782         1.311293          0.073389         0.029848
# min         1.000000         0.000000       -121.933128        37.389587
# 25%         1.000000         1.000000        -73.991852        40.737392
# 50%         2.000000         1.000000        -73.981743        40.754093
# 75%         2.000000         2.000000        -73.967400        40.768394
# max         2.000000         9.000000        -69.248917        42.814938
#
#        dropoff_longitude  dropoff_latitude
# count      625134.000000     625134.000000
# mean          -73.973458         40.751816
# std             0.072565          0.035824
# min          -121.933327         36.601322
# 25%           -73.991318         40.736000
# ...

# %%
# Check what pickup_datetime looks like
print("=== PICKUP DATETIME SAMPLE ===")
print(df['pickup_datetime'].head(10))

print("\n=== DATA TYPE OF DATETIME COLUMN ===")
print(df['pickup_datetime'].dtype)
# Out:
# === PICKUP DATETIME SAMPLE ===
# 0    6/30/2016 23:59
# 1    6/30/2016 23:59
# 2    6/30/2016 23:59
# 3    6/30/2016 23:59
# 4    6/30/2016 23:59
# 5    6/30/2016 23:59
# 6    6/30/2016 23:59
# 7    6/30/2016 23:59
# 8    6/30/2016 23:58
# 9    6/30/2016 23:58
# Name: pickup_datetime, dtype: object
#
# === DATA TYPE OF DATETIME COLUMN ===
# object

# %%
print("=== GPS COORDINATE RANGES ===")
print(f"Pickup Longitude  : {df['pickup_longitude'].min():.4f} to {df['pickup_longitude'].max():.4f}")
print(f"Pickup Latitude   : {df['pickup_latitude'].min():.4f} to {df['pickup_latitude'].max():.4f}")
print(f"Dropoff Longitude : {df['dropoff_longitude'].min():.4f} to {df['dropoff_longitude'].max():.4f}")
print(f"Dropoff Latitude  : {df['dropoff_latitude'].min():.4f} to {df['dropoff_latitude'].max():.4f}")

print("\n=== OFFICIAL NYC BOUNDARY RANGES (source: NYC.gov) ===")
print("Longitude should be between -74.269 and -73.699")
print("Latitude  should be between  40.496 and  40.916")
# Out:
# === GPS COORDINATE RANGES ===
# Pickup Longitude  : -121.9331 to -69.2489
# Pickup Latitude   : 37.3896 to 42.8149
# Dropoff Longitude : -121.9333 to -67.4968
# Dropoff Latitude  : 36.6013 to 48.8576
#
# === OFFICIAL NYC BOUNDARY RANGES (source: NYC.gov) ===
# Longitude should be between -74.269 and -73.699
# Latitude  should be between  40.496 and  40.916

# %%
print("=== DUPLICATE ROWS ===")
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

print("\n=== DUPLICATE IDs ===")
duplicate_ids = df['id'].duplicated().sum()
print(f"Number of duplicate trip IDs: {duplicate_ids}")
# Out:
# === DUPLICATE ROWS ===
# Number of duplicate rows: 0
#
# === DUPLICATE IDs ===
# Number of duplicate trip IDs: 0
